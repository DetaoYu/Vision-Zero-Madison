# %% [markdown]
# CS 638
#
# Vision Zero Project
#
# Team member: Boyu Shen, Detao Yu(Vincent), Jing Huang

# %% [markdown]
# <font size=5>Section 1: SLIDE SUPPLEMENT</font>

# %%
from IPython.display import Image

# %%
Image(filename = "1.png")

# %% [markdown]
# Methodology: First I figured out how many crashes per manner. Then I figured out what were drivers doing under each manner.

# %% [markdown]
# Conclusion: Most crashes happened at interactions are angle(side) collisions and rear end collisions. Rather than going straight, left turn and right turn are more easily to cause angle collisions. Stopped in traffic and slowing or stopped caused most rear end collisions. My suggestions are update Traffic light system, like The pedestrian lights will light up first than turn signals, more isolation strip to avoid drivers to go on the wrong side of the road.

# %%
from IPython.display import Image
Image(filename = "finalmap2.png")

# %% [markdown]
# Remarks: This map only includes the locations and numbers of accidents that happened on highways under the reason following too close.
#
# Methodology: I made a new data set that extracts data of accidents happened only on highways, then refined the data set to only include accidents happening under the reason following too close.(Before I extract the data, I cleaned the missing data.) Then I used a python folium package to draw a map of those refined accdients. The data set include the coordinates of every accidents, and python automaticly divide the map into different districts. Each circle on the map provides information about the number of accidents happening in that district.

# %% [markdown]
# <font size=5>Section 2: EXTRA PLOTS</font>

# %%
Image(filename = "finalplot2.png")

# %% [markdown]
# Conclusions:From the above plot, it is obvious that non-incapacitating is the most common injury severity. There are nealy a half of the non-incapacitating people not transported to medical facility while for other severity level, a majority of victims are transported to hospital. Here I'm assuming that since people can handle non-incapacitating injuries by themselves, so victims of this injury level are likely to not be transported to hospital.

# %%
Image(filename = "MAP.png")

# %% [markdown]
# Remarks: This plot only incluedes accidents whose victims are non-incapacitating and not transported to medical facility.
#
# Conlusions:From the above plot, we can see that the West Johnson Street is the place where people who are non-capacitating are likely to be not transported to the medical facility.(The place is represented by the red circle).This is the place where more medical facility are needed.

# %%
Image(filename = "finalplot3.png")

# %% [markdown]
# Remarks: The left-side y-axis represents the percentages of accidents of different severity levels in that hour.(bar)The right-side y-axis represents the number of alcohol-related accidents.(line)
#
# Conclusions: At 2am, the number of alcohol-related accidents reaches the peak, because people tend to drink at night parties. 2am is the time when parties usually end. The percentage of level incapacitating increases from 1am to 2am. After 2am, the number of alcohol-related accidents goes down and the percentage of incapacitating also goes down.
# Overall , the variation trend of level "incapacitating" and the number of alcohol-related accidents are similar.

# %%
Image(filename = "finalplot4.png")

# %% [markdown]
# Conclusion:We can see the trends of intersection and non-intersection related accidents are pretty similar. For the time period from 4pm to 5pm , the non-intersection part has higher counts. Further plot may needed to analyze what was happening on the non-intersection part from 4pm to 5pm.

# %%
Image(filename = "2.png")

# %% [markdown]
# There are two peaks in this bar graph (7am-8am and 15pm-17pm), which are commuter time, more crashes will happen during this time because of heavy traffic. Most accidents happened on city street urban which verifies this point. 81% increase from 6am to 7am. 13% increase from 14 pm to 15pm.

# %%
Image(filename="7.png")

# %% [markdown]
# We can observe the number of alcohol-related crashes distributed by age, the red dash line is 21 years old. Below this age, there are under-age youth are involved in an alcohol-related crash. We can tell that as people get older, they are not likely to get involved in an alcohol-related crash. People aged 20-26 have most crashes.

# %%
Image(filename="17.png")

# %% [markdown]
# Conclusion: Most crashes happened at interactions are angle(side) collisions and rear end collisions. Rather than going straight, left turn and right turn are more easily to cause angle collisions. Stopped in traffic and slowing or stopped caused most rear end collisions. My suggestions are update Traffic light system, like The pedestrian lights will light up first than turn signals, more isolation strip to avoid drivers to go on the wrong side of the road.

# %%
Image(filename="20.png")

# %% [markdown]
# In every month of 2018, there are the most accidents in city street urban. The variance of each kind of road type is very small, so in 2018, city street urban always has the most accidents happening.
# In these city street urban, the street name that the most accidents happening are East Washington Avenue, South Gammon Road, and Pflaum Road. In South Gammon Road, there are significant increases in March and August; in East Washington Avenue, the accidents happen more often when the weather gets colder (increase since May to November and decrease since February). Also, in more than half of the months in 2018, East Washington Avenue has the most number of accidents.

# %%
Image(filename="22.png")

# %% [markdown]
# Car, truck tractor (semi attached), straight truck(insert truck) have very flat trend.
# Motorcycle, bicycle, moped, since these three types of vehicles do not have any protection. If they have a crash, it is very easy for them to be thrown out so that they get injured. The accidents of school bus just cause injuries and property damage, there is no fatalities caused by school bus. I have searched on the Internet, the reason of why school bus has accidents is that other vehicles crashed on the school bus or due to the bad weather or slippery road, the school bus is not under control. So the school bus can be called “the most safety bus”.

# %%
Image(filename="23.png")

# %% [markdown]
# This plot shows that due to overspeed of wreckers, the number of accidents happen by age. From this plot, we can see that there are two peaks, which are 19 years old and 22 years old (two red dash line). In the age from 19 to 22, people are inadolescence and may be easily emotional and cannot help overspeeding.
# 16 is the minimum age that is proved to drive a car, but from this plot, we can see that there are many accidents happen in people who is younger than 16 years old (green dash line).
# Also, I found that there are several crashes for people older than 70 years old. From the website, I found that in US, there is no limit for the maximum age of drivers. From website, in Wisconsin in 2013, there are about 278 thousand, older than 75 years old people hold legal driving licences and there are 217 people who is older than 100 years old hold legal driving licences. It is a very shocking data.

# %%
Image(filename="24.png")

# %% [markdown]
# Over 20 years, male are always easy to overspeed than female. Since 2009, the trend tends to smooth, it is because there is a Wisconsin Statewide Speed Management Guidelines proposed in 2009. All of the limitations of overspeed has been very clear since 2009.

# %%
Image(filename="25.png")

# %% [markdown]
# This graph tells that for all people involved in the accidents, in this five year stages, how the number of injuries changed based on the age.
# People who is 25 to 44 years old have the most injury accidents.
# All of the year stage have very steady trend, but there is a significant reduce from 2016 to 2017. I think it is because there is an Wisconsin Strategic Highway Safety Plan 2017-2020 proposed in 2016.
# The plan's goal:
# By 2020,
# • 5% reduction in number of fatalities (2% reduction each year)
# • 5% reduction in the rate of fatalities per 100 million VMT (2% reduction each year)
# • 10% reduction in number of serious injuries (5% reduction each year)
# • 10% reduction in the rate of serious injuries per 100 million VMT (5% reduction each year)
# • 10% reduction in number of non-motorized fatalities and non-motorized serious injuries (5% reduction each year).
# (https://wisconsindot.gov/Documents/safety/education/frms-pubs/strategichwy-17-20.pdf)

# %% [markdown]
# <font size=5>Section 3: DOCUMENTATION</font>

# %% [markdown]
# ## Data Source
# [Wisconsin Traffic Operation and Safety Laboratory](https://transportal.cee.wisc.edu/services/crash-data/)

# %% [markdown]
# ## Important packages and visualization tools
# 1. Data process: csv, numpy, pandas
#
# 2. Visuazalition: matplotlib, ggplot, folium, seaborn
